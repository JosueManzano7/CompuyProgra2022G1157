# %% [markdown]
# <a href="https://colab.research.google.com/github/JosueManzano7/CompuyProgra2022G1157/blob/main/Tarea7_ManzanoPonceJosue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TAREA 7- MANZANO ONCE JOSUE

# %% [markdown]
# #PROBLEMA 3.1
# Escriba un progrma tal que dado como datos 270 números enteros, obtenga la suma de los números impares y el promedio de los números pares.

# %%
SUMPAR=0
SUMIMP=0
CUEPAR=0
I=1
while I<=10:
    NUM=int(input(f"Dame el valor {I}: "))
    if NUM!=0:
        if NUM%2==0:
            SUMPAR+=NUM
            CUEPAR+=1
        else:
            SUMIMP+=NUM
    I+=1
PROPAR=SUMPAR/CUEPAR
print("PROMEDIO DE NUMEROS PARES: ", PROPAR)
print("SUMA DE NUMEROS IMPARES: ", SUMIMP)
# Out:
# Dame el valor 1: 9
# Dame el valor 2: 0
# Dame el valor 3: 7
# Dame el valor 4: 5
# Dame el valor 5: 45
# Dame el valor 6: 65
# Dame el valor 7: 80
# Dame el valor 8: 1
# Dame el valor 9: 75
# Dame el valor 10: 100
# PROMEDIO DE NUMEROS PARES:  90.0
# SUMA DE NUMEROS IMPARES:  207

# %%
import random
e=[random.randint(1,1000) for x in range(270)]#generador de numeroes enteros
SUMPAR=0
SUMIMP=0
CUEPAR=0
I=1
while I<=270:
    NUM=e[I-1]
    print(f"Valor {I}: {e[I-1]}")
    if NUM!=0:
        if NUM%2==0:
            SUMPAR+=NUM
            CUEPAR+=1
        else:
            SUMIMP+=NUM
    I+=1
PROPAR=SUMPAR/CUEPAR
print("PROMEDIO DE NUMEROS PARES: ", PROPAR)
print("SUMA DE NUMEROS IMPARES: ", SUMIMP)
# Out:
# Valor 1: 554
# Valor 2: 186
# Valor 3: 156
# Valor 4: 770
# Valor 5: 768
# Valor 6: 593
# Valor 7: 50
# Valor 8: 14
# Valor 9: 556
# Valor 10: 979
# Valor 11: 94
# Valor 12: 235
# Valor 13: 247
# Valor 14: 658
# Valor 15: 500
# Valor 16: 517
# Valor 17: 664
# Valor 18: 452
# Valor 19: 536
# Valor 20: 281
# Valor 21: 893
# Valor 22: 951
# Valor 23: 334
# Valor 24: 877
# Valor 25: 765
# Valor 26: 316
# Valor 27: 930
# Valor 28: 119
# Valor 29: 321
# Valor 30: 954
# Valor 31: 726
# Valor 32: 837
# Valor 33: 511
# Valor 34: 349
# Valor 35: 281
# Valor 36: 895
# Valor 37: 821
# Valor 38: 649
# Valor 39: 80
# Valor 40: 882
# Valor 41: 647
# Valor 42: 167
# Valor 43: 436
# Valor 44: 369
# Valor 45: 658
# Valor 46: 691
# Valor 47: 519
# Valor 48: 852
# Valor 49: 67
# Valor 50: 129
# Valor 51: 798
# Valor 52: 173
# Valor 53: 796
# Valor 54: 982
# Valor 55: 672
# Valor 56: 675
# Valor 57: 931
# Valor 58: 147
# Valor 59: 756
# Valor 60: 355
# Valor 61: 167
# Valor 62: 674
# Valor 63: 463
# ...

# %% [markdown]
# #PROBLEMA 3.2
# Escriba un programa que obtenga la suma e imprima los términos de la siguiente serie:
#
# 2,5, 7, 10, 12,15, 17, . . 1 800

# %%
BAND="T"
SUMSER=0
I=2
while I<=1800:
    SUMSER+=1
    print(I)
    if BAND=="T":
        BAND="F"
        I+=3
    else:
        BAND="T"
        I+=2
print("NUMERO DE TERMINOS DE LA SERIE: ",SUMSER)
# Out:
# 2
# 5
# 7
# 10
# 12
# 15
# 17
# 20
# 22
# 25
# 27
# 30
# 32
# 35
# 37
# 40
# 42
# 45
# 47
# 50
# 52
# 55
# 57
# 60
# 62
# 65
# 67
# 70
# 72
# 75
# 77
# 80
# 82
# 85
# 87
# 90
# 92
# 95
# 97
# 100
# 102
# 105
# 107
# 110
# 112
# 115
# 117
# 120
# 122
# 125
# 127
# 130
# 132
# 135
# 137
# 140
# 142
# 145
# 147
# 150
# 152
# 155
# 157
# 160
# 162
# 165
# 167
# 170
# 172
# 175
# 177
# 180
# 182
# 185
# 187
# 190
# 192
# 195
# 197
# 200
# 202
# 205
# 207
# 210
# 212
# 215
# 217
# 220
# 222
# 225
# 227
# 230
# 232
# 235
# 237
# 240
# 242
# 245
# 247
# 250
# 252
# 255
# 257
# 260
# 262
# 265
# 267
# 270
# 272
# 275
# 277
# 280
# 282
# 285
# 287
# 290
# 292
# 295
# 297
# 300
# 302
# 305
# 307
# 310
# 312
# 315
# 317
# 320
# 322
# 325
# 327
# 330
# 332
# 335
# 337
# 340
# 342
# 345
# 347
# 350
# 352
# 355
# 357
# 360
# 362
# 365
# 367
# 370
# 372
# 375
# 377
# 380
# 382
# 385
# 387
# 390
# 392
# 395
# 397
# 400
# 402
# 405
# 407
# 410
# 412
# 415
# 417
# 420
# 422
# 425
# 427
# 430
# 432
# ...

# %% [markdown]
# #PROGAMA 3.3
# Escriba un diagrama de flujo que lea un número entero N y calcule el resultado de la siguiente serie:
#
# 1-(1/2)+(1/3)-(1/4)+...+(1/N)

# %%
SERIE=0
N=int(input("Dame el número de términos de la serie: "))
BAND="T"
I=1
while(I<=N):
    if BAND=="T":
        SERIE=SERIE+(1/I)
        BAND="F"
    else:
        SERIE=SERIE-(1/I)
        BAND="T"
    I+=1
print("RESULTADO CON ",N," TERMINOS: ",round(SERIE,4))
# Out:
# Dame el número de términos de la serie: 9
# RESULTADO CON  9  TERMINOS:  0.7456

# %% [markdown]
# #PROBLEMA 3.4
# Calcule el aumento de sueldo para un grupo de empleados de una empresa teniendo en cuenta el siguiente criterio:
#
# - Si el sueldo es inferior a \$1000 : Aumento 15%
# - Si el sueldo es mayor o igual a \$1000 : Aumento 12%
#
# Imprima el sueldo nuevo del trabajador y el total de nómina de la empresa, considerando este nuevo aumento.

# %%
NOM=0
SUE=float(input("Dame el sueldo del trabajador 1: "))
i=1
while SUE!=-1:
    if SUE<1000:
        NSUE=SUE*1.15
    else:
        NSUE=SUE*1.12
    NOM=NOM+NSUE
    print(round(NSUE,2))
    SUE=float(input(f"Dame el sueldo del trabajador {i+1}: "))
    i+=1

print(NOM)
# Out:
# Dame el sueldo del trabajador 1: 855
# 983.25
# Dame el sueldo del trabajador: 2: 760.32
# 874.37
# Dame el sueldo del trabajador: 3: 1100.20
# 1232.22
# Dame el sueldo del trabajador: 4: 614
# 706.1
# Dame el sueldo del trabajador: 5: 2600
# 2912.0
# Dame el sueldo del trabajador: 6: 817.50
# 940.12
# Dame el sueldo del trabajador: 7: 1280.30
# 1433.94
# Dame el sueldo del trabajador: 8: 687
# 790.05
# Dame el sueldo del trabajador: 9: -1
# 9872.053
